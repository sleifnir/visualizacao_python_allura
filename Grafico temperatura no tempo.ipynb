# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("monitoramento_tempo.csv")
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df["data"] = pd.to_datetime(df["data"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
plt.plot(df["data"],df["temperatura"]) 
# plota grafico no eixo x e y

# %%
plt.figure(figsize=(15,8))
plt.plot(df["data"],df["temperatura"])

# %%
plt.figure(figsize=(15,8))
plt.plot(df["data"],df["temperatura"])
plt.title("Temperatura por Tempo")
# Out:
# Text(0.5, 1.0, 'Temperatura por Tempo')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
plt.plot(df["data"],df["temperatura"])
plt.title("Temperatura no momento")
# Out:
# Text(0.5, 1.0, 'Temperatura no momento')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"],df["temperatura"])
eixo.set_title("Temperatura no momento")
eixo.set_ylabel("Temperatura")
eixo.set_xlabel("data")
# Out:
# Text(0.5, 0, 'data')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"],df["temperatura"])
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel("Temperatura",fontsize=20)
eixo.set_xlabel("data",fontsize=20)
# Out:
# Text(0.5, 0, 'data')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"],df["temperatura"],color="green")
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel("Temperatura",fontsize=20)
eixo.set_xlabel("data",fontsize=20)
eixo.legend(["Temperatura"],loc="lower right",fontsize=15)

# %%
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/home/odin/.vscode/extensions/ms-toolsai.jupyter-2022.7.1102252217/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 158, in _start_notebook
#
#     from notebook import notebookapp as app
#
#   File "/home/odin/.local/lib/python3.8/site-packages/notebook/notebookapp.py", line 76, in <module>
#
#     from .base.handlers import Template404, RedirectWithParams
#
#   File "/home/odin/.local/lib/python3.8/site-packages/notebook/base/handlers.py", line 24, in <module>
#
#     import prometheus_client
#
# ModuleNotFoundError: No module named 'prometheus_client'
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# Traceback (most recent call last):
#
#   File "/home/odin/.vscode/extensions/ms-toolsai.jupyter-2022.7.1102252217/pythonFiles/vscode_datascience_helpers/daemon/daemon_python.py", line 54, in _decorator
#
#     return func(self, *args, **kwargs)
#
#   File "/home/odin/.vscode/extensions/ms-toolsai.jupyter-2022.7.1102252217/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 111, in m_exec_module_observable
#
#     self._start_notebook(args, cwd, env)
#
#   File "/home/odin/.vscode/extensions/ms-toolsai.jupyter-2022.7.1102252217/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 160, in _start_notebook
#
#     from notebook import app as app
#
# ImportError: cannot import name 'app' from 'notebook' (/home/odin/.local/lib/python3.8/site-packages/notebook/__init__.py)
#
#
#
# Failed to run jupyter as observable with args notebook --no-browser --notebook-dir="/home/odin/allura/visualizacao_python_allura" --config=/tmp/66d16bc1-06b4-4417-a179-b1fbdabf9967/jupyter_notebook_config.py --NotebookApp.iopub_data_rate_limit=10000000000.0.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
